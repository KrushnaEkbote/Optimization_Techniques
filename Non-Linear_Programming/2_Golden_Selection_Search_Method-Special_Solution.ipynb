# %% [markdown]
# # Golden_Selection_Search_Method-Special_Solution

# %%
itr=int(input('Enter number of iterations: '))
print('')

b = 5
aw=0
bw=1
i=0

while i<itr:
	k=i+1
	lw=bw-aw
	u=aw+(0.618*lw)
	v=bw-(0.618*lw)
	zu=(25*(u**2))+(54/(5*u))
	zv=(25*(v**2))+(54/(5*v))
	print('Iteration ',k,':')
	print('W1 = ',u)
	print('W2 = ',v)
	
	if zu<zv:
		aw = v
		print('x1 =',(b*aw))
		print ('x2 =',(b*bw),'\n')
		
	else:
		bw = u
		print('x1 =',(b*aw))
		print ('x2 =',(b*bw),'\n')
	i+=1;
	
	#take output of range in x
# Out:
# Iteration  1 :
# W1 =  0.618
# W2 =  0.382
# x1 = 1.9100000000000001
# x2 = 5
#
# Iteration  2 :
# W1 =  0.763924
# W2 =  0.6180760000000001
# x1 = 1.9100000000000001
# x2 = 3.8196200000000005
#
# Iteration  3 :
# W1 =  0.618029032
# W2 =  0.527894968
# x1 = 2.63947484
# x2 = 3.8196200000000005
#
# Iteration  4 :
# W1 =  0.673760909776
# W2 =  0.6180580582240001
# x1 = 2.63947484
# x2 = 3.36880454888
#
# Iteration  5 :
# W1 =  0.618040120017568
# W2 =  0.583615757758432
# x1 = 2.63947484
# x2 = 3.09020060008784
#
# Iteration  6 :
# W1 =  0.5836046719468571
# W2 =  0.562330416070711
# x1 = 2.811652080353555
# x2 = 3.09020060008784
#
# Iteration  7 :
# W1 =  0.5967590131098687
# W2 =  0.5836115229784103
# x1 = 2.9180576148920516
# x2 = 3.09020060008784
#
# Iteration  8 :
# W1 =  0.6048883959486098
# W2 =  0.5967632470473686
# x1 = 2.9180576148920516
# x2 = 3.024441979743049
#
# Iteration  9 :
# W1 =  0.5967606304739936
# W2 =  0.5917392884530265
# x1 = 2.9586964422651323
# ...
